# %% [markdown]
# # Central Limit Theorem
#
# In this notebook, we will use ```numpy``` to draw samples from several different types of distributions and check whether the sample mean actually converges to a normal distribution as sample size gets larger.

# %% [markdown]
# ### A. Uniform Distribution
#
# When the distribution is uniform, there is equal chance in getting amy number between the specified minimum and maximum.
#
# 1. Generate samples with ```np.random.random()```.
# 2. Compute sample means with ```np.mean()```.
# 3. Plot a histogram with ```matplotlib.pyplot.hist()```.

# %%
# Draw samples from np.random.random()

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

x = np.random.random(5)

# Show the samples and plot a histogram
print(x)
plt.hist(x)
plt.draw()
# Out:
# [ 0.41698562  0.25309412  0.78762879  0.05678374  0.00876674]

# %%
# Repeat 500 times, calculate the sample mean each time

S = []
for i in range(500):
    S.append(np.mean(np.random.random(5)))

plt.hist(S)
# Out:
# (array([  14.,   36.,   58.,   99.,  102.,   95.,   60.,   29.,    6.,    1.]),
#  array([ 0.17184337,  0.24662785,  0.32141232,  0.3961968 ,  0.47098127,
#          0.54576575,  0.62055023,  0.6953347 ,  0.77011918,  0.84490366,
#          0.91968813]),
#  <a list of 10 Patch objects>)

# %%
# Repeat 500 times with sample size increased to 30

S = []
for i in range(500):
    S.append(np.mean(np.random.random(30)))

plt.hist(S)
# Out:
# (array([   4.,   11.,   30.,   75.,  114.,  120.,   74.,   51.,   20.,    1.]),
#  array([ 0.33570285,  0.36716166,  0.39862047,  0.43007928,  0.46153808,
#          0.49299689,  0.5244557 ,  0.5559145 ,  0.58737331,  0.61883212,
#          0.65029093]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# If you want to plot a smoothed line based on the histogram, use ```seaborn.distplot()```:

# %%
import seaborn as sns
sns.distplot(S,hist=True,kde=True)
# Out:
# /opt/conda/lib/python3.6/site-packages/seaborn/distributions.py:215: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   color=hist_color, **hist_kws)

# %% [markdown]
# ### B. Bernoulli Distribution
#
# Bernoulli distribution gives 1 with chance $p$ and 0 with chance $1-p$.
#
# 1. Generate samples with ```scipy.stats.bernoulli()```.
# 2. Compute sample means with ```np.mean()```.
# 3. Plot a histogram with ```seaborn.displot()```.
#
# We will use a Bernoulli distribution with $p=0.6$, meaning that we will get 1's 60% of the time.

# %%
# Bernoulli trials

from scipy.stats import bernoulli

x = bernoulli.rvs(p=0.6,size=5)

# Show the samples and plot a histogram
print(x)
plt.hist(x,bins=2)
plt.draw()
# Out:
# [0 1 1 1 1]

# %%
# Repeat 500 times, calculate the sample mean each time

S = []
for i in range(500):
    S.append(np.mean(bernoulli.rvs(p=0.6,size=5)))

sns.distplot(S,hist=True,kde=True)
# Out:
# /opt/conda/lib/python3.6/site-packages/seaborn/distributions.py:215: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   color=hist_color, **hist_kws)

# %%
# Repeat 500 times with sample size increased to 30

S = []
for i in range(500):
    S.append(np.mean(bernoulli.rvs(p=0.6,size=30)))

sns.distplot(S,hist=True,kde=True)
# Out:
# /opt/conda/lib/python3.6/site-packages/seaborn/distributions.py:215: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   color=hist_color, **hist_kws)

# %% [markdown]
# ### C. Exponential Distribution
#
# In an exponential distribution, the chance of getting a number goes smaller when the number is larger.
#
# 1. Generate samples with ```np.random.exponential()```.
# 2. Compute sample means with ```np.mean()```.
# 3. Plot a histogram with ```seaborn.displot()```.

# %%
# Exponential distribution
x = np.random.exponential(size=100)

# Show the samples and plot a histogram
plt.hist(x)
plt.draw()

# %%
# Repeat 500 times, calculate the sample mean each time

S = []
for i in range(500):
    S.append(np.mean(np.random.exponential(size=5)))

sns.distplot(S,hist=True,kde=True)
# Out:
# /opt/conda/lib/python3.6/site-packages/seaborn/distributions.py:215: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   color=hist_color, **hist_kws)

# %%
# Repeat 500 times with sample size increased to 30

S = []
for i in range(500):
    S.append(np.mean(np.random.exponential(size=30)))

sns.distplot(S,hist=True,kde=True)
# Out:
# /opt/conda/lib/python3.6/site-packages/seaborn/distributions.py:215: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   color=hist_color, **hist_kws)

# %% [markdown]
# ### Variance Estimate
#
# How accurate does the sample variance approximate the population variance?
# We will use the Bernoulli distribution as an example.
#
# $$
# Var[X] = E[X^2] - E[X]^2
# $$
#
# For Bernoulli trials, this gives a population variance of $Var[x] = 0.6 - 0.6^2 = 0.24$.

# %%
# Sample size = 5
S = []
for i in range(500):
    S.append(np.var(bernoulli.rvs(p=0.6,size=5)))
sns.distplot(S,hist=True,kde=True)
# Out:
# /opt/conda/lib/python3.6/site-packages/seaborn/distributions.py:215: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   color=hist_color, **hist_kws)

# %%
# Sample size = 30
S = []
for i in range(500):
    S.append(np.var(bernoulli.rvs(p=0.6,size=30)))
sns.distplot(S,hist=True,kde=True)
# Out:
# /opt/conda/lib/python3.6/site-packages/seaborn/distributions.py:215: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   color=hist_color, **hist_kws)

# %%
# Sample size = 1000
S = []
for i in range(500):
    S.append(np.var(bernoulli.rvs(p=0.6,size=1000)))
sns.distplot(S,hist=True,kde=True)
# Out:
# /opt/conda/lib/python3.6/site-packages/seaborn/distributions.py:215: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   color=hist_color, **hist_kws)

# %% [markdown]
# As we can see, when the sample size is small the sample variance is very likely to be different from the population variance.
#
# When sample size is large, sample variance does give a good estimate of population variance.
